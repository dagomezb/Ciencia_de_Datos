# %% [markdown]
# <a href="https://colab.research.google.com/github/dagomezb/Ciencia_de_Datos/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introducción a Seaborn**

# %%
# Importando librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Importando Datasets
country_data = pd.read_csv('countries-of-the-world.csv', decimal=",")
mpg = pd.read_csv('mpg.csv')
student_data = pd.read_csv('student-alcohol-consumption.csv', index_col=0)
survey = pd.read_csv('young-people-survey-responses.csv', index_col=0)

# %%
country_data.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %% [markdown]
# **Scatterplot**

# %%
sns.scatterplot(data=country_data, x="GDP ($ per capita)", y="Phones (per 1000)")

plt.show()

# %% [markdown]
# **Ejercicio**
#
# Cambie el diagrama de dispersión para que muestre el porcentaje de la población que sabe leer y escribir (percent_literate) en el eje y.

# %% [markdown]
# **Countplot**

# %% [markdown]
# ¿Cuál Región tiene el mayor número de países?

# %%
sns.countplot(y=country_data.Region)

plt.show()

# %% [markdown]
# # **Relplot**

# %% [markdown]
# En este ejercicio, exploraremos el conjunto de datos mpg, que contiene una fila por modelo de coche e incluye información como el año de fabricación del coche, el número de millas por galón ("M.P.G.") que alcanza, la potencia de su motor (medida en "caballos") y su país de origen.
#
# ¿Cuál es la relación entre la potencia del motor de un coche ("caballos") y su eficiencia de combustible ("mpg")? ¿Y cómo varía esta relación según el número de cilindros ("cylinders") que tenga el coche?

# %%
sns.relplot(data=mpg,x="horsepower",y="mpg",size="cylinders")

plt.show()

# %%
sns.relplot(x="horsepower", y="mpg", 
            data=mpg, kind="scatter", 
            size="cylinders",
            hue="cylinders")

# Show plot
plt.show()

# %% [markdown]
# ## Lineplot

# %%
sns.relplot(x="model_year", y="mpg", 
            data=mpg, kind="line")

plt.show()

# %% [markdown]
# **Pregunta**
# ¿Cuál de las siguientes NO es una interpretación correcta de este gráfico lineal?
#
# *Posibles respuestas*
#
# El promedio de millas por galón ha aumentado generalmente con el tiempo.
#
# La distribución de millas por galón es menor en 1973 comparado con 1977.
#
# El intervalo de confianza del 95% para el promedio de millas por galón en 1970 es aproximadamente 16 - 19.5 millas por galón.
#
# Este gráfico supone que nuestros datos son una muestra aleatoria de todos los coches de EE.UU., Europa y Japón.

# %% [markdown]
# # Ejemplo
#
# Utilice relplot() y el DataFrame mpg para crear un gráfico de dispersión con "aceleración" en el eje x y "mpg" en el eje y. Varía el estilo y el color de los puntos del gráfico según el país de origen ("origin").

# %%
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", 
            ci=None, style="origin", 
            hue="origin")

# Show plot
plt.show()

# %%
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", 
            ci=None, style="origin", 
            hue="origin",
            dashes=False,
            markers=True)

# Show plot
plt.show()

# %% [markdown]
# # **Catplot**

# %% [markdown]
# ### Ejercicios
#
# Explorar conjuntos de datos
#
# Utiliza los DataFrames importados en la primera celda para explorar los datos y practicar tus habilidades.
#
# * A partir de country_data, crea un gráfico de dispersión para observar la relación entre el PIB y la alfabetización. Utiliza el color para segmentar los puntos de datos por regiones.
#
# * Utiliza mpg para crear un gráfico de líneas con model_year en el eje x y weight en el eje y. Cree líneas diferenciadas para cada país de origen (origen).
#
# * Cree un diagrama de cajas a partir de student_data para explorar la relación entre el número de suspensos (failures) y la nota media final (G3).
#
# * Crea un diagrama de barras a partir de encuesta para comparar cómo difiere la soledad según los valores de uso de Internet.
#
# * Asegúrate de añadir títulos y etiquetas a tus gráficos y de ajustar su formato para facilitar su lectura.

# %% [markdown]
# # **Personalización**

# %%
sns.set_style


sns.set_palette()

sns.set_context()

#Titulo FacetGrid
g = sns...
g.fig.suptitle("Titulo")
g.set_titles("This is {col_name}")

# Labels
g.set(xlabel= ..., ylabel = )

plt.xticks(rotation=90)
plt.show()
